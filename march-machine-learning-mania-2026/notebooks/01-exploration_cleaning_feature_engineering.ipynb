# %%
import polars as pl
import polars.selectors as cs
from src import exploration_cleaning_methods as ecm

# %% [markdown]
# **Men's NCCA data**

# %%
m_regular_season_detailed_lf: pl.LazyFrame = pl.scan_csv("../data/raw/MRegularSeasonDetailedResults.csv")
m_regular_season_detailed_lf.head(10).collect()
# Out:
# shape: (10, 34)
# ┌────────┬────────┬─────────┬────────┬───┬─────┬──────┬──────┬─────┐
# │ Season ┆ DayNum ┆ WTeamID ┆ WScore ┆ … ┆ LTO ┆ LStl ┆ LBlk ┆ LPF │
# │ ---    ┆ ---    ┆ ---     ┆ ---    ┆   ┆ --- ┆ ---  ┆ ---  ┆ --- │
# │ i64    ┆ i64    ┆ i64     ┆ i64    ┆   ┆ i64 ┆ i64  ┆ i64  ┆ i64 │
# ╞════════╪════════╪═════════╪════════╪═══╪═════╪══════╪══════╪═════╡
# │ 2003   ┆ 10     ┆ 1104    ┆ 68     ┆ … ┆ 18  ┆ 9    ┆ 2    ┆ 20  │
# │ 2003   ┆ 10     ┆ 1272    ┆ 70     ┆ … ┆ 12  ┆ 8    ┆ 6    ┆ 16  │
# │ 2003   ┆ 11     ┆ 1266    ┆ 73     ┆ … ┆ 12  ┆ 2    ┆ 5    ┆ 23  │
# │ 2003   ┆ 11     ┆ 1296    ┆ 56     ┆ … ┆ 19  ┆ 4    ┆ 3    ┆ 23  │
# │ 2003   ┆ 11     ┆ 1400    ┆ 77     ┆ … ┆ 10  ┆ 7    ┆ 1    ┆ 14  │
# │ 2003   ┆ 11     ┆ 1458    ┆ 81     ┆ … ┆ 19  ┆ 4    ┆ 3    ┆ 25  │
# │ 2003   ┆ 12     ┆ 1161    ┆ 80     ┆ … ┆ 30  ┆ 10   ┆ 4    ┆ 28  │
# │ 2003   ┆ 12     ┆ 1186    ┆ 75     ┆ … ┆ 15  ┆ 14   ┆ 8    ┆ 18  │
# │ 2003   ┆ 12     ┆ 1194    ┆ 71     ┆ … ┆ 25  ┆ 8    ┆ 2    ┆ 18  │
# │ 2003   ┆ 12     ┆ 1458    ┆ 84     ┆ … ┆ 18  ┆ 1    ┆ 3    ┆ 18  │
# └────────┴────────┴─────────┴────────┴───┴─────┴──────┴──────┴─────┘

# %%
m_regular_season_detailed_lf = m_regular_season_detailed_lf.with_columns(cs.numeric().exclude("WLoc").cast(pl.Int16))
m_regular_season_detailed_lf.head(10).collect()
# Out:
# shape: (10, 34)
# ┌────────┬────────┬─────────┬────────┬───┬─────┬──────┬──────┬─────┐
# │ Season ┆ DayNum ┆ WTeamID ┆ WScore ┆ … ┆ LTO ┆ LStl ┆ LBlk ┆ LPF │
# │ ---    ┆ ---    ┆ ---     ┆ ---    ┆   ┆ --- ┆ ---  ┆ ---  ┆ --- │
# │ i16    ┆ i16    ┆ i16     ┆ i16    ┆   ┆ i16 ┆ i16  ┆ i16  ┆ i16 │
# ╞════════╪════════╪═════════╪════════╪═══╪═════╪══════╪══════╪═════╡
# │ 2003   ┆ 10     ┆ 1104    ┆ 68     ┆ … ┆ 18  ┆ 9    ┆ 2    ┆ 20  │
# │ 2003   ┆ 10     ┆ 1272    ┆ 70     ┆ … ┆ 12  ┆ 8    ┆ 6    ┆ 16  │
# │ 2003   ┆ 11     ┆ 1266    ┆ 73     ┆ … ┆ 12  ┆ 2    ┆ 5    ┆ 23  │
# │ 2003   ┆ 11     ┆ 1296    ┆ 56     ┆ … ┆ 19  ┆ 4    ┆ 3    ┆ 23  │
# │ 2003   ┆ 11     ┆ 1400    ┆ 77     ┆ … ┆ 10  ┆ 7    ┆ 1    ┆ 14  │
# │ 2003   ┆ 11     ┆ 1458    ┆ 81     ┆ … ┆ 19  ┆ 4    ┆ 3    ┆ 25  │
# │ 2003   ┆ 12     ┆ 1161    ┆ 80     ┆ … ┆ 30  ┆ 10   ┆ 4    ┆ 28  │
# │ 2003   ┆ 12     ┆ 1186    ┆ 75     ┆ … ┆ 15  ┆ 14   ┆ 8    ┆ 18  │
# │ 2003   ┆ 12     ┆ 1194    ┆ 71     ┆ … ┆ 25  ┆ 8    ┆ 2    ┆ 18  │
# │ 2003   ┆ 12     ┆ 1458    ┆ 84     ┆ … ┆ 18  ┆ 1    ┆ 3    ┆ 18  │
# └────────┴────────┴─────────┴────────┴───┴─────┴──────┴──────┴─────┘

# %%
m_regular_season_detailed_lf = ecm.create_team_season_profile(m_regular_season_detailed_lf)
m_regular_season_detailed_lf.head(10).collect()
# Out:
# shape: (10, 13)
# ┌────────┬────────┬───────────┬─────────────┬───┬─────────────┬──────────┬────────────┬────────────┐
# │ Season ┆ TeamID ┆ TeamScore ┆ OpponentSco ┆ … ┆ DefEfficien ┆ TeamEFG  ┆ OpponentEF ┆ TurnoverRa │
# │ ---    ┆ ---    ┆ ---       ┆ re          ┆   ┆ cy          ┆ ---      ┆ G          ┆ te         │
# │ i16    ┆ i16    ┆ f64       ┆ ---         ┆   ┆ ---         ┆ f64      ┆ ---        ┆ ---        │
# │        ┆        ┆           ┆ f64         ┆   ┆ f64         ┆          ┆ f64        ┆ f64        │
# ╞════════╪════════╪═══════════╪═════════════╪═══╪═════════════╪══════════╪════════════╪════════════╡
# │ 2017   ┆ 1366   ┆ 83.925926 ┆ 91.518519   ┆ … ┆ 109.221103  ┆ 0.501463 ┆ 0.525615   ┆ 0.178687   │
# │ 2015   ┆ 1453   ┆ 67.666667 ┆ 60.933333   ┆ … ┆ 94.453205   ┆ 0.498985 ┆ 0.465392   ┆ 0.184422   │
# │ 2019   ┆ 1369   ┆ 70.413793 ┆ 77.344828   ┆ … ┆ 108.424212  ┆ 0.505629 ┆ 0.530615   ┆ 0.201206   │
# │ 2023   ┆ 1452   ┆ 76.30303  ┆ 71.030303   ┆ … ┆ 100.832664  ┆ 0.517366 ┆ 0.508744   ┆ 0.174426   │
# │ 2016   ┆ 1328   ┆ 80.40625  ┆ 70.4375     ┆ … ┆ 97.566145   ┆ 0.547413 ┆ 0.468395   ┆ 0.179906   │
# │ 2015   ┆ 1213   ┆ 67.827586 ┆ 68.862069   ┆ … ┆ 108.004115  ┆ 0.510127 ┆ 0.497889   ┆ 0.170598   │
# │ 2025   ┆ 1173   ┆ 75.16129  ┆ 70.548387   ┆ … ┆ 103.951189  ┆ 0.529564 ┆ 0.507606   ┆ 0.147071   │
# │ 2018   ┆ 1393   ┆ 67.545455 ┆ 64.545455   ┆ … ┆ 97.913277   ┆ 0.475678 ┆ 0.471474   ┆ 0.191596   │
# │ 2018   ┆ 1119   ┆ 73.724138 ┆ 75.172414   ┆ … ┆ 104.965055  ┆ 0.527178 ┆ 0.526802   ┆ 0.186155   │
# │ 2022   ┆ 1420   ┆ 73.354839 ┆ 72.903226   ┆ … ┆ 104.711208  ┆ 0.527737 ┆ 0.528286   ┆ 0.155202   │
# └────────┴────────┴───────────┴─────────────┴───┴─────────────┴──────────┴────────────┴────────────┘

# %%
m_tourney_detailed_lf: pl.LazyFrame = pl.scan_csv("../data/raw/MNCAATourneyDetailedResults.csv")
m_tourney_detailed_lf.head(10).collect()
# Out:
# shape: (10, 34)
# ┌────────┬────────┬─────────┬────────┬───┬─────┬──────┬──────┬─────┐
# │ Season ┆ DayNum ┆ WTeamID ┆ WScore ┆ … ┆ LTO ┆ LStl ┆ LBlk ┆ LPF │
# │ ---    ┆ ---    ┆ ---     ┆ ---    ┆   ┆ --- ┆ ---  ┆ ---  ┆ --- │
# │ i64    ┆ i64    ┆ i64     ┆ i64    ┆   ┆ i64 ┆ i64  ┆ i64  ┆ i64 │
# ╞════════╪════════╪═════════╪════════╪═══╪═════╪══════╪══════╪═════╡
# │ 2003   ┆ 134    ┆ 1421    ┆ 92     ┆ … ┆ 15  ┆ 5    ┆ 0    ┆ 22  │
# │ 2003   ┆ 136    ┆ 1112    ┆ 80     ┆ … ┆ 17  ┆ 10   ┆ 3    ┆ 15  │
# │ 2003   ┆ 136    ┆ 1113    ┆ 84     ┆ … ┆ 12  ┆ 2    ┆ 5    ┆ 18  │
# │ 2003   ┆ 136    ┆ 1141    ┆ 79     ┆ … ┆ 21  ┆ 6    ┆ 6    ┆ 21  │
# │ 2003   ┆ 136    ┆ 1143    ┆ 76     ┆ … ┆ 14  ┆ 5    ┆ 8    ┆ 19  │
# │ 2003   ┆ 136    ┆ 1163    ┆ 58     ┆ … ┆ 11  ┆ 8    ┆ 4    ┆ 22  │
# │ 2003   ┆ 136    ┆ 1181    ┆ 67     ┆ … ┆ 19  ┆ 5    ┆ 4    ┆ 19  │
# │ 2003   ┆ 136    ┆ 1211    ┆ 74     ┆ … ┆ 10  ┆ 7    ┆ 6    ┆ 24  │
# │ 2003   ┆ 136    ┆ 1228    ┆ 65     ┆ … ┆ 14  ┆ 6    ┆ 5    ┆ 16  │
# │ 2003   ┆ 136    ┆ 1242    ┆ 64     ┆ … ┆ 13  ┆ 6    ┆ 1    ┆ 15  │
# └────────┴────────┴─────────┴────────┴───┴─────┴──────┴──────┴─────┘

# %%
m_tourney_detailed_lf = m_tourney_detailed_lf.with_columns(cs.numeric().exclude("WLoc").cast(pl.Int16))
m_tourney_detailed_lf.head(10).collect()
# Out:
# shape: (10, 34)
# ┌────────┬────────┬─────────┬────────┬───┬─────┬──────┬──────┬─────┐
# │ Season ┆ DayNum ┆ WTeamID ┆ WScore ┆ … ┆ LTO ┆ LStl ┆ LBlk ┆ LPF │
# │ ---    ┆ ---    ┆ ---     ┆ ---    ┆   ┆ --- ┆ ---  ┆ ---  ┆ --- │
# │ i16    ┆ i16    ┆ i16     ┆ i16    ┆   ┆ i16 ┆ i16  ┆ i16  ┆ i16 │
# ╞════════╪════════╪═════════╪════════╪═══╪═════╪══════╪══════╪═════╡
# │ 2003   ┆ 134    ┆ 1421    ┆ 92     ┆ … ┆ 15  ┆ 5    ┆ 0    ┆ 22  │
# │ 2003   ┆ 136    ┆ 1112    ┆ 80     ┆ … ┆ 17  ┆ 10   ┆ 3    ┆ 15  │
# │ 2003   ┆ 136    ┆ 1113    ┆ 84     ┆ … ┆ 12  ┆ 2    ┆ 5    ┆ 18  │
# │ 2003   ┆ 136    ┆ 1141    ┆ 79     ┆ … ┆ 21  ┆ 6    ┆ 6    ┆ 21  │
# │ 2003   ┆ 136    ┆ 1143    ┆ 76     ┆ … ┆ 14  ┆ 5    ┆ 8    ┆ 19  │
# │ 2003   ┆ 136    ┆ 1163    ┆ 58     ┆ … ┆ 11  ┆ 8    ┆ 4    ┆ 22  │
# │ 2003   ┆ 136    ┆ 1181    ┆ 67     ┆ … ┆ 19  ┆ 5    ┆ 4    ┆ 19  │
# │ 2003   ┆ 136    ┆ 1211    ┆ 74     ┆ … ┆ 10  ┆ 7    ┆ 6    ┆ 24  │
# │ 2003   ┆ 136    ┆ 1228    ┆ 65     ┆ … ┆ 14  ┆ 6    ┆ 5    ┆ 16  │
# │ 2003   ┆ 136    ┆ 1242    ┆ 64     ┆ … ┆ 13  ┆ 6    ┆ 1    ┆ 15  │
# └────────┴────────┴─────────┴────────┴───┴─────┴──────┴──────┴─────┘

# %%
m_tourney_detailed_lf = ecm.create_team_season_profile(m_tourney_detailed_lf)
m_tourney_detailed_lf.head(10).collect()
# Out:
# shape: (10, 13)
# ┌────────┬────────┬───────────┬─────────────┬───┬─────────────┬──────────┬────────────┬────────────┐
# │ Season ┆ TeamID ┆ TeamScore ┆ OpponentSco ┆ … ┆ DefEfficien ┆ TeamEFG  ┆ OpponentEF ┆ TurnoverRa │
# │ ---    ┆ ---    ┆ ---       ┆ re          ┆   ┆ cy          ┆ ---      ┆ G          ┆ te         │
# │ i16    ┆ i16    ┆ f64       ┆ ---         ┆   ┆ ---         ┆ f64      ┆ ---        ┆ ---        │
# │        ┆        ┆           ┆ f64         ┆   ┆ f64         ┆          ┆ f64        ┆ f64        │
# ╞════════╪════════╪═══════════╪═════════════╪═══╪═════════════╪══════════╪════════════╪════════════╡
# │ 2016   ┆ 1396   ┆ 70.0      ┆ 72.0        ┆ … ┆ 103.671706  ┆ 0.484848 ┆ 0.398551   ┆ 0.173223   │
# │ 2016   ┆ 1403   ┆ 61.0      ┆ 71.0        ┆ … ┆ 109.907121  ┆ 0.527778 ┆ 0.578431   ┆ 0.211241   │
# │ 2015   ┆ 1318   ┆ 65.0      ┆ 69.0        ┆ … ┆ 113.955409  ┆ 0.518182 ┆ 0.595745   ┆ 0.25498    │
# │ 2016   ┆ 1181   ┆ 77.333333 ┆ 77.0        ┆ … ┆ 112.681767  ┆ 0.548025 ┆ 0.502225   ┆ 0.13785    │
# │ 2019   ┆ 1101   ┆ 44.0      ┆ 79.0        ┆ … ┆ 125.347084  ┆ 0.367925 ┆ 0.571429   ┆ 0.15444    │
# │ 2016   ┆ 1452   ┆ 56.0      ┆ 70.0        ┆ … ┆ 100.683207  ┆ 0.336538 ┆ 0.372727   ┆ 0.315073   │
# │ 2023   ┆ 1331   ┆ 51.0      ┆ 74.0        ┆ … ┆ 115.130299  ┆ 0.365079 ┆ 0.53125    ┆ 0.132743   │
# │ 2025   ┆ 1219   ┆ 63.0      ┆ 75.0        ┆ … ┆ 126.156434  ┆ 0.528302 ┆ 0.5        ┆ 0.14944    │
# │ 2023   ┆ 1388   ┆ 59.0      ┆ 60.5        ┆ … ┆ 95.36477    ┆ 0.433673 ┆ 0.529184   ┆ 0.129229   │
# │ 2024   ┆ 1389   ┆ 49.0      ┆ 83.0        ┆ … ┆ 117.107584  ┆ 0.327273 ┆ 0.613208   ┆ 0.0952     │
# └────────┴────────┴───────────┴─────────────┴───┴─────────────┴──────────┴────────────┴────────────┘

# %%
m_tourney_seed_lf: pl.LazyFrame = pl.scan_csv("../data/raw/MNCAATourneySeeds.csv")
m_tourney_seed_lf.head(10).collect()
# Out:
# shape: (10, 3)
# ┌────────┬──────┬────────┐
# │ Season ┆ Seed ┆ TeamID │
# │ ---    ┆ ---  ┆ ---    │
# │ i64    ┆ str  ┆ i64    │
# ╞════════╪══════╪════════╡
# │ 1985   ┆ W01  ┆ 1207   │
# │ 1985   ┆ W02  ┆ 1210   │
# │ 1985   ┆ W03  ┆ 1228   │
# │ 1985   ┆ W04  ┆ 1260   │
# │ 1985   ┆ W05  ┆ 1374   │
# │ 1985   ┆ W06  ┆ 1208   │
# │ 1985   ┆ W07  ┆ 1393   │
# │ 1985   ┆ W08  ┆ 1396   │
# │ 1985   ┆ W09  ┆ 1439   │
# │ 1985   ┆ W10  ┆ 1177   │
# └────────┴──────┴────────┘

# %%
m_tourney_seed_lf = m_tourney_seed_lf.with_columns(cs.numeric().exclude("Seed").cast(pl.Int16))
m_tourney_seed_lf.head(10).collect()
# Out:
# shape: (10, 3)
# ┌────────┬──────┬────────┐
# │ Season ┆ Seed ┆ TeamID │
# │ ---    ┆ ---  ┆ ---    │
# │ i16    ┆ str  ┆ i16    │
# ╞════════╪══════╪════════╡
# │ 1985   ┆ W01  ┆ 1207   │
# │ 1985   ┆ W02  ┆ 1210   │
# │ 1985   ┆ W03  ┆ 1228   │
# │ 1985   ┆ W04  ┆ 1260   │
# │ 1985   ┆ W05  ┆ 1374   │
# │ 1985   ┆ W06  ┆ 1208   │
# │ 1985   ┆ W07  ┆ 1393   │
# │ 1985   ┆ W08  ┆ 1396   │
# │ 1985   ┆ W09  ┆ 1439   │
# │ 1985   ┆ W10  ┆ 1177   │
# └────────┴──────┴────────┘

# %%
m_tourney_seed_lf = ecm.clean_seed(m_tourney_seed_lf)
m_tourney_seed_lf.head(10).collect()
# Out:
# shape: (10, 3)
# ┌────────┬──────┬────────┐
# │ Season ┆ Seed ┆ TeamID │
# │ ---    ┆ ---  ┆ ---    │
# │ i16    ┆ i8   ┆ i16    │
# ╞════════╪══════╪════════╡
# │ 2015   ┆ 1    ┆ 1437   │
# │ 2015   ┆ 2    ┆ 1438   │
# │ 2015   ┆ 3    ┆ 1328   │
# │ 2015   ┆ 4    ┆ 1257   │
# │ 2015   ┆ 5    ┆ 1320   │
# │ 2015   ┆ 6    ┆ 1344   │
# │ 2015   ┆ 7    ┆ 1277   │
# │ 2015   ┆ 8    ┆ 1301   │
# │ 2015   ┆ 9    ┆ 1261   │
# │ 2015   ┆ 10   ┆ 1208   │
# └────────┴──────┴────────┘

# %%
m_golden_tabel_lf: pl.LazyFrame = ecm.merge_seed_with_regular(m_tourney_seed_lf, m_regular_season_detailed_lf)
m_golden_tabel_lf.head(10).collect()
# Out:
# shape: (10, 14)
# ┌────────┬────────┬───────────┬───────────────┬───┬──────────┬─────────────┬──────────────┬──────┐
# │ Season ┆ TeamID ┆ TeamScore ┆ OpponentScore ┆ … ┆ TeamEFG  ┆ OpponentEFG ┆ TurnoverRate ┆ Seed │
# │ ---    ┆ ---    ┆ ---       ┆ ---           ┆   ┆ ---      ┆ ---         ┆ ---          ┆ ---  │
# │ i16    ┆ i16    ┆ f64       ┆ f64           ┆   ┆ f64      ┆ f64         ┆ f64          ┆ i8   │
# ╞════════╪════════╪═══════════╪═══════════════╪═══╪══════════╪═════════════╪══════════════╪══════╡
# │ 2018   ┆ 1403   ┆ 75.242424 ┆ 64.69697      ┆ … ┆ 0.528639 ┆ 0.466368    ┆ 0.183535     ┆ 3    │
# │ 2018   ┆ 1325   ┆ 75.633333 ┆ 76.5          ┆ … ┆ 0.511985 ┆ 0.499075    ┆ 0.180496     ┆ null │
# │ 2026   ┆ 1308   ┆ 73.315789 ┆ 72.473684     ┆ … ┆ 0.493331 ┆ 0.495721    ┆ 0.146482     ┆ null │
# │ 2022   ┆ 1123   ┆ 73.966667 ┆ 77.4          ┆ … ┆ 0.517829 ┆ 0.525483    ┆ 0.186766     ┆ null │
# │ 2017   ┆ 1228   ┆ 70.483871 ┆ 70.032258     ┆ … ┆ 0.510388 ┆ 0.507333    ┆ 0.182852     ┆ null │
# │ 2019   ┆ 1305   ┆ 80.666667 ┆ 66.666667     ┆ … ┆ 0.540561 ┆ 0.477774    ┆ 0.143311     ┆ 7    │
# │ 2019   ┆ 1153   ┆ 71.705882 ┆ 62.205882     ┆ … ┆ 0.489598 ┆ 0.482854    ┆ 0.160403     ┆ 7    │
# │ 2024   ┆ 1429   ┆ 78.967742 ┆ 71.548387     ┆ … ┆ 0.544722 ┆ 0.494885    ┆ 0.150452     ┆ 8    │
# │ 2016   ┆ 1123   ┆ 69.709677 ┆ 66.516129     ┆ … ┆ 0.521547 ┆ 0.469958    ┆ 0.194691     ┆ null │
# │ 2016   ┆ 1311   ┆ 66.096774 ┆ 77.548387     ┆ … ┆ 0.472943 ┆ 0.505746    ┆ 0.218631     ┆ null │
# └────────┴────────┴───────────┴───────────────┴───┴──────────┴─────────────┴──────────────┴──────┘

# %%
del m_regular_season_detailed_lf, m_tourney_seed_lf

# %%
m_tourney_matchups: pl.LazyFrame = pl.scan_csv("../data/raw/MNCAATourneyDetailedResults.csv")
m_tourney_matchups = ecm.prepare_tourney_matchups(m_tourney_matchups)
m_tourney_matchups.head(10).collect()
# Out:
# shape: (10, 5)
# ┌────────┬─────────┬─────────┬────────┬────────┐
# │ Season ┆ ATeamID ┆ BTeamID ┆ DayNum ┆ Target │
# │ ---    ┆ ---     ┆ ---     ┆ ---    ┆ ---    │
# │ i16    ┆ i16     ┆ i16     ┆ i16    ┆ i8     │
# ╞════════╪═════════╪═════════╪════════╪════════╡
# │ 2015   ┆ 1214    ┆ 1264    ┆ 134    ┆ 1      │
# │ 2015   ┆ 1279    ┆ 1140    ┆ 134    ┆ 1      │
# │ 2015   ┆ 1173    ┆ 1129    ┆ 135    ┆ 1      │
# │ 2015   ┆ 1352    ┆ 1316    ┆ 135    ┆ 1      │
# │ 2015   ┆ 1112    ┆ 1411    ┆ 136    ┆ 1      │
# │ 2015   ┆ 1116    ┆ 1459    ┆ 136    ┆ 1      │
# │ 2015   ┆ 1139    ┆ 1400    ┆ 136    ┆ 1      │
# │ 2015   ┆ 1153    ┆ 1345    ┆ 136    ┆ 1      │
# │ 2015   ┆ 1207    ┆ 1186    ┆ 136    ┆ 1      │
# │ 2015   ┆ 1209    ┆ 1124    ┆ 136    ┆ 1      │
# └────────┴─────────┴─────────┴────────┴────────┘

# %% [markdown]
# **Women's NCCA data**

# %%
w_regular_season_detailed_lf: pl.LazyFrame = pl.scan_csv("../data/raw/WRegularSeasonDetailedResults.csv")
w_regular_season_detailed_lf.head(10).collect()
# Out:
# shape: (10, 34)
# ┌────────┬────────┬─────────┬────────┬───┬─────┬──────┬──────┬─────┐
# │ Season ┆ DayNum ┆ WTeamID ┆ WScore ┆ … ┆ LTO ┆ LStl ┆ LBlk ┆ LPF │
# │ ---    ┆ ---    ┆ ---     ┆ ---    ┆   ┆ --- ┆ ---  ┆ ---  ┆ --- │
# │ i64    ┆ i64    ┆ i64     ┆ i64    ┆   ┆ i64 ┆ i64  ┆ i64  ┆ i64 │
# ╞════════╪════════╪═════════╪════════╪═══╪═════╪══════╪══════╪═════╡
# │ 2010   ┆ 11     ┆ 3103    ┆ 63     ┆ … ┆ 23  ┆ 7    ┆ 6    ┆ 19  │
# │ 2010   ┆ 11     ┆ 3104    ┆ 73     ┆ … ┆ 20  ┆ 4    ┆ 2    ┆ 27  │
# │ 2010   ┆ 11     ┆ 3110    ┆ 71     ┆ … ┆ 15  ┆ 6    ┆ 0    ┆ 15  │
# │ 2010   ┆ 11     ┆ 3111    ┆ 63     ┆ … ┆ 11  ┆ 14   ┆ 5    ┆ 14  │
# │ 2010   ┆ 11     ┆ 3119    ┆ 74     ┆ … ┆ 14  ┆ 4    ┆ 2    ┆ 14  │
# │ 2010   ┆ 11     ┆ 3120    ┆ 70     ┆ … ┆ 29  ┆ 9    ┆ 1    ┆ 28  │
# │ 2010   ┆ 11     ┆ 3125    ┆ 85     ┆ … ┆ 15  ┆ 10   ┆ 0    ┆ 22  │
# │ 2010   ┆ 11     ┆ 3132    ┆ 76     ┆ … ┆ 28  ┆ 8    ┆ 1    ┆ 17  │
# │ 2010   ┆ 11     ┆ 3138    ┆ 87     ┆ … ┆ 21  ┆ 11   ┆ 1    ┆ 28  │
# │ 2010   ┆ 11     ┆ 3140    ┆ 73     ┆ … ┆ 22  ┆ 2    ┆ 1    ┆ 15  │
# └────────┴────────┴─────────┴────────┴───┴─────┴──────┴──────┴─────┘

# %%
w_regular_season_detailed_lf = w_regular_season_detailed_lf.with_columns(cs.numeric().exclude("WLoc").cast(pl.Int16))
w_regular_season_detailed_lf.head(10).collect()
# Out:
# shape: (10, 34)
# ┌────────┬────────┬─────────┬────────┬───┬─────┬──────┬──────┬─────┐
# │ Season ┆ DayNum ┆ WTeamID ┆ WScore ┆ … ┆ LTO ┆ LStl ┆ LBlk ┆ LPF │
# │ ---    ┆ ---    ┆ ---     ┆ ---    ┆   ┆ --- ┆ ---  ┆ ---  ┆ --- │
# │ i16    ┆ i16    ┆ i16     ┆ i16    ┆   ┆ i16 ┆ i16  ┆ i16  ┆ i16 │
# ╞════════╪════════╪═════════╪════════╪═══╪═════╪══════╪══════╪═════╡
# │ 2010   ┆ 11     ┆ 3103    ┆ 63     ┆ … ┆ 23  ┆ 7    ┆ 6    ┆ 19  │
# │ 2010   ┆ 11     ┆ 3104    ┆ 73     ┆ … ┆ 20  ┆ 4    ┆ 2    ┆ 27  │
# │ 2010   ┆ 11     ┆ 3110    ┆ 71     ┆ … ┆ 15  ┆ 6    ┆ 0    ┆ 15  │
# │ 2010   ┆ 11     ┆ 3111    ┆ 63     ┆ … ┆ 11  ┆ 14   ┆ 5    ┆ 14  │
# │ 2010   ┆ 11     ┆ 3119    ┆ 74     ┆ … ┆ 14  ┆ 4    ┆ 2    ┆ 14  │
# │ 2010   ┆ 11     ┆ 3120    ┆ 70     ┆ … ┆ 29  ┆ 9    ┆ 1    ┆ 28  │
# │ 2010   ┆ 11     ┆ 3125    ┆ 85     ┆ … ┆ 15  ┆ 10   ┆ 0    ┆ 22  │
# │ 2010   ┆ 11     ┆ 3132    ┆ 76     ┆ … ┆ 28  ┆ 8    ┆ 1    ┆ 17  │
# │ 2010   ┆ 11     ┆ 3138    ┆ 87     ┆ … ┆ 21  ┆ 11   ┆ 1    ┆ 28  │
# │ 2010   ┆ 11     ┆ 3140    ┆ 73     ┆ … ┆ 22  ┆ 2    ┆ 1    ┆ 15  │
# └────────┴────────┴─────────┴────────┴───┴─────┴──────┴──────┴─────┘

# %%
w_regular_season_detailed_lf = ecm.create_team_season_profile(w_regular_season_detailed_lf)
w_regular_season_detailed_lf.head(10).collect()
# Out:
# shape: (10, 13)
# ┌────────┬────────┬───────────┬─────────────┬───┬─────────────┬──────────┬────────────┬────────────┐
# │ Season ┆ TeamID ┆ TeamScore ┆ OpponentSco ┆ … ┆ DefEfficien ┆ TeamEFG  ┆ OpponentEF ┆ TurnoverRa │
# │ ---    ┆ ---    ┆ ---       ┆ re          ┆   ┆ cy          ┆ ---      ┆ G          ┆ te         │
# │ i16    ┆ i16    ┆ f64       ┆ ---         ┆   ┆ ---         ┆ f64      ┆ ---        ┆ ---        │
# │        ┆        ┆           ┆ f64         ┆   ┆ f64         ┆          ┆ f64        ┆ f64        │
# ╞════════╪════════╪═══════════╪═════════════╪═══╪═════════════╪══════════╪════════════╪════════════╡
# │ 2026   ┆ 3333   ┆ 67.238095 ┆ 61.666667   ┆ … ┆ 88.704399   ┆ 0.513837 ┆ 0.439206   ┆ 0.211195   │
# │ 2018   ┆ 3217   ┆ 69.035714 ┆ 65.714286   ┆ … ┆ 95.394831   ┆ 0.491168 ┆ 0.45126    ┆ 0.222281   │
# │ 2022   ┆ 3186   ┆ 58.107143 ┆ 65.571429   ┆ … ┆ 90.243755   ┆ 0.394045 ┆ 0.445125   ┆ 0.188847   │
# │ 2023   ┆ 3260   ┆ 55.8      ┆ 64.766667   ┆ … ┆ 95.918501   ┆ 0.417409 ┆ 0.493937   ┆ 0.199386   │
# │ 2018   ┆ 3249   ┆ 74.16     ┆ 63.88       ┆ … ┆ 82.559244   ┆ 0.432772 ┆ 0.484859   ┆ 0.190546   │
# │ 2018   ┆ 3187   ┆ 65.096774 ┆ 67.483871   ┆ … ┆ 87.435273   ┆ 0.405011 ┆ 0.446421   ┆ 0.230176   │
# │ 2021   ┆ 3307   ┆ 80.333333 ┆ 67.5        ┆ … ┆ 88.664045   ┆ 0.528981 ┆ 0.446113   ┆ 0.158875   │
# │ 2022   ┆ 3208   ┆ 69.137931 ┆ 59.0        ┆ … ┆ 80.541345   ┆ 0.461289 ┆ 0.415842   ┆ 0.208131   │
# │ 2017   ┆ 3174   ┆ 57.1      ┆ 58.0        ┆ … ┆ 88.953651   ┆ 0.422314 ┆ 0.429843   ┆ 0.226528   │
# │ 2023   ┆ 3149   ┆ 52.413793 ┆ 71.068966   ┆ … ┆ 95.35175    ┆ 0.380724 ┆ 0.476517   ┆ 0.266618   │
# └────────┴────────┴───────────┴─────────────┴───┴─────────────┴──────────┴────────────┴────────────┘

# %%
w_tourney_detailed_lf: pl.LazyFrame = pl.scan_csv("../data/raw/WNCAATourneyDetailedResults.csv")
w_tourney_detailed_lf.head(10).collect()
# Out:
# shape: (10, 34)
# ┌────────┬────────┬─────────┬────────┬───┬─────┬──────┬──────┬─────┐
# │ Season ┆ DayNum ┆ WTeamID ┆ WScore ┆ … ┆ LTO ┆ LStl ┆ LBlk ┆ LPF │
# │ ---    ┆ ---    ┆ ---     ┆ ---    ┆   ┆ --- ┆ ---  ┆ ---  ┆ --- │
# │ i64    ┆ i64    ┆ i64     ┆ i64    ┆   ┆ i64 ┆ i64  ┆ i64  ┆ i64 │
# ╞════════╪════════╪═════════╪════════╪═══╪═════╪══════╪══════╪═════╡
# │ 2010   ┆ 138    ┆ 3124    ┆ 69     ┆ … ┆ 18  ┆ 4    ┆ 1    ┆ 18  │
# │ 2010   ┆ 138    ┆ 3173    ┆ 67     ┆ … ┆ 8   ┆ 8    ┆ 6    ┆ 22  │
# │ 2010   ┆ 138    ┆ 3181    ┆ 72     ┆ … ┆ 16  ┆ 6    ┆ 4    ┆ 20  │
# │ 2010   ┆ 138    ┆ 3199    ┆ 75     ┆ … ┆ 16  ┆ 5    ┆ 4    ┆ 24  │
# │ 2010   ┆ 138    ┆ 3207    ┆ 62     ┆ … ┆ 10  ┆ 3    ┆ 4    ┆ 12  │
# │ 2010   ┆ 138    ┆ 3208    ┆ 64     ┆ … ┆ 12  ┆ 11   ┆ 3    ┆ 20  │
# │ 2010   ┆ 138    ┆ 3211    ┆ 82     ┆ … ┆ 18  ┆ 12   ┆ 5    ┆ 16  │
# │ 2010   ┆ 138    ┆ 3234    ┆ 70     ┆ … ┆ 13  ┆ 10   ┆ 2    ┆ 21  │
# │ 2010   ┆ 138    ┆ 3246    ┆ 83     ┆ … ┆ 22  ┆ 8    ┆ 1    ┆ 25  │
# │ 2010   ┆ 138    ┆ 3261    ┆ 60     ┆ … ┆ 17  ┆ 7    ┆ 5    ┆ 20  │
# └────────┴────────┴─────────┴────────┴───┴─────┴──────┴──────┴─────┘

# %%
w_tourney_detailed_lf = w_tourney_detailed_lf.with_columns(cs.numeric().exclude("WLoc").cast(pl.Int16))
w_tourney_detailed_lf.head(10).collect()
# Out:
# shape: (10, 34)
# ┌────────┬────────┬─────────┬────────┬───┬─────┬──────┬──────┬─────┐
# │ Season ┆ DayNum ┆ WTeamID ┆ WScore ┆ … ┆ LTO ┆ LStl ┆ LBlk ┆ LPF │
# │ ---    ┆ ---    ┆ ---     ┆ ---    ┆   ┆ --- ┆ ---  ┆ ---  ┆ --- │
# │ i16    ┆ i16    ┆ i16     ┆ i16    ┆   ┆ i16 ┆ i16  ┆ i16  ┆ i16 │
# ╞════════╪════════╪═════════╪════════╪═══╪═════╪══════╪══════╪═════╡
# │ 2010   ┆ 138    ┆ 3124    ┆ 69     ┆ … ┆ 18  ┆ 4    ┆ 1    ┆ 18  │
# │ 2010   ┆ 138    ┆ 3173    ┆ 67     ┆ … ┆ 8   ┆ 8    ┆ 6    ┆ 22  │
# │ 2010   ┆ 138    ┆ 3181    ┆ 72     ┆ … ┆ 16  ┆ 6    ┆ 4    ┆ 20  │
# │ 2010   ┆ 138    ┆ 3199    ┆ 75     ┆ … ┆ 16  ┆ 5    ┆ 4    ┆ 24  │
# │ 2010   ┆ 138    ┆ 3207    ┆ 62     ┆ … ┆ 10  ┆ 3    ┆ 4    ┆ 12  │
# │ 2010   ┆ 138    ┆ 3208    ┆ 64     ┆ … ┆ 12  ┆ 11   ┆ 3    ┆ 20  │
# │ 2010   ┆ 138    ┆ 3211    ┆ 82     ┆ … ┆ 18  ┆ 12   ┆ 5    ┆ 16  │
# │ 2010   ┆ 138    ┆ 3234    ┆ 70     ┆ … ┆ 13  ┆ 10   ┆ 2    ┆ 21  │
# │ 2010   ┆ 138    ┆ 3246    ┆ 83     ┆ … ┆ 22  ┆ 8    ┆ 1    ┆ 25  │
# │ 2010   ┆ 138    ┆ 3261    ┆ 60     ┆ … ┆ 17  ┆ 7    ┆ 5    ┆ 20  │
# └────────┴────────┴─────────┴────────┴───┴─────┴──────┴──────┴─────┘

# %%
w_tourney_detailed_lf = ecm.create_team_season_profile(w_tourney_detailed_lf)
w_tourney_detailed_lf.head(10).collect()
# Out:
# shape: (10, 13)
# ┌────────┬────────┬───────────┬─────────────┬───┬─────────────┬──────────┬────────────┬────────────┐
# │ Season ┆ TeamID ┆ TeamScore ┆ OpponentSco ┆ … ┆ DefEfficien ┆ TeamEFG  ┆ OpponentEF ┆ TurnoverRa │
# │ ---    ┆ ---    ┆ ---       ┆ re          ┆   ┆ cy          ┆ ---      ┆ G          ┆ te         │
# │ i16    ┆ i16    ┆ f64       ┆ ---         ┆   ┆ ---         ┆ f64      ┆ ---        ┆ ---        │
# │        ┆        ┆           ┆ f64         ┆   ┆ f64         ┆          ┆ f64        ┆ f64        │
# ╞════════╪════════╪═══════════╪═════════════╪═══╪═════════════╪══════════╪════════════╪════════════╡
# │ 2019   ┆ 3177   ┆ 78.0      ┆ 89.0        ┆ … ┆ 114.066004  ┆ 0.493151 ┆ 0.614754   ┆ 0.152381   │
# │ 2019   ┆ 3283   ┆ 68.0      ┆ 64.333333   ┆ … ┆ 88.532423   ┆ 0.450603 ┆ 0.379364   ┆ 0.195621   │
# │ 2015   ┆ 3107   ┆ 52.0      ┆ 54.0        ┆ … ┆ 81.663516   ┆ 0.333333 ┆ 0.522222   ┆ 0.201005   │
# │ 2017   ┆ 3177   ┆ 79.5      ┆ 79.5        ┆ … ┆ 112.644428  ┆ 0.547571 ┆ 0.480087   ┆ 0.190725   │
# │ 2015   ┆ 3304   ┆ 69.0      ┆ 72.0        ┆ … ┆ 102.893891  ┆ 0.491379 ┆ 0.449275   ┆ 0.261888   │
# │ 2016   ┆ 3280   ┆ 57.333333 ┆ 73.333333   ┆ … ┆ 104.102666  ┆ 0.361508 ┆ 0.533456   ┆ 0.244593   │
# │ 2022   ┆ 3261   ┆ 73.5      ┆ 78.0        ┆ … ┆ 95.668785   ┆ 0.400636 ┆ 0.497718   ┆ 0.126025   │
# │ 2024   ┆ 3394   ┆ 55.0      ┆ 87.0        ┆ … ┆ 122.23393   ┆ 0.349206 ┆ 0.6        ┆ 0.241884   │
# │ 2023   ┆ 3424   ┆ 59.0      ┆ 71.0        ┆ … ┆ 105.029586  ┆ 0.441667 ┆ 0.491525   ┆ 0.184856   │
# │ 2016   ┆ 3355   ┆ 69.5      ┆ 68.5        ┆ … ┆ 96.006047   ┆ 0.480159 ┆ 0.453947   ┆ 0.194088   │
# └────────┴────────┴───────────┴─────────────┴───┴─────────────┴──────────┴────────────┴────────────┘

# %%
w_tourney_seed_lf: pl.LazyFrame = pl.scan_csv("../data/raw/WNCAATourneySeeds.csv")
w_tourney_seed_lf.head(10).collect()
# Out:
# shape: (10, 3)
# ┌────────┬──────┬────────┐
# │ Season ┆ Seed ┆ TeamID │
# │ ---    ┆ ---  ┆ ---    │
# │ i64    ┆ str  ┆ i64    │
# ╞════════╪══════╪════════╡
# │ 1998   ┆ W01  ┆ 3330   │
# │ 1998   ┆ W02  ┆ 3163   │
# │ 1998   ┆ W03  ┆ 3112   │
# │ 1998   ┆ W04  ┆ 3301   │
# │ 1998   ┆ W05  ┆ 3272   │
# │ 1998   ┆ W06  ┆ 3438   │
# │ 1998   ┆ W07  ┆ 3208   │
# │ 1998   ┆ W08  ┆ 3307   │
# │ 1998   ┆ W09  ┆ 3304   │
# │ 1998   ┆ W10  ┆ 3203   │
# └────────┴──────┴────────┘

# %%
w_tourney_seed_lf = w_tourney_seed_lf.with_columns(cs.numeric().exclude("WLoc").cast(pl.Int16))
w_tourney_seed_lf.head(10).collect()
# Out:
# shape: (10, 3)
# ┌────────┬──────┬────────┐
# │ Season ┆ Seed ┆ TeamID │
# │ ---    ┆ ---  ┆ ---    │
# │ i16    ┆ str  ┆ i16    │
# ╞════════╪══════╪════════╡
# │ 1998   ┆ W01  ┆ 3330   │
# │ 1998   ┆ W02  ┆ 3163   │
# │ 1998   ┆ W03  ┆ 3112   │
# │ 1998   ┆ W04  ┆ 3301   │
# │ 1998   ┆ W05  ┆ 3272   │
# │ 1998   ┆ W06  ┆ 3438   │
# │ 1998   ┆ W07  ┆ 3208   │
# │ 1998   ┆ W08  ┆ 3307   │
# │ 1998   ┆ W09  ┆ 3304   │
# │ 1998   ┆ W10  ┆ 3203   │
# └────────┴──────┴────────┘

# %%
w_tourney_seed_lf = ecm.clean_seed(w_tourney_seed_lf)
w_tourney_seed_lf.head(10).collect()
# Out:
# shape: (10, 3)
# ┌────────┬──────┬────────┐
# │ Season ┆ Seed ┆ TeamID │
# │ ---    ┆ ---  ┆ ---    │
# │ i16    ┆ i8   ┆ i16    │
# ╞════════╪══════╪════════╡
# │ 2015   ┆ 1    ┆ 3163   │
# │ 2015   ┆ 2    ┆ 3246   │
# │ 2015   ┆ 3    ┆ 3257   │
# │ 2015   ┆ 4    ┆ 3143   │
# │ 2015   ┆ 5    ┆ 3400   │
# │ 2015   ┆ 6    ┆ 3378   │
# │ 2015   ┆ 7    ┆ 3173   │
# │ 2015   ┆ 8    ┆ 3353   │
# │ 2015   ┆ 9    ┆ 3371   │
# │ 2015   ┆ 10   ┆ 3235   │
# └────────┴──────┴────────┘

# %%
w_golden_table_lf: pl.LazyFrame = ecm.merge_seed_with_regular(w_tourney_seed_lf, w_regular_season_detailed_lf)
w_golden_table_lf.head(10).collect()
# Out:
# shape: (10, 14)
# ┌────────┬────────┬───────────┬───────────────┬───┬──────────┬─────────────┬──────────────┬──────┐
# │ Season ┆ TeamID ┆ TeamScore ┆ OpponentScore ┆ … ┆ TeamEFG  ┆ OpponentEFG ┆ TurnoverRate ┆ Seed │
# │ ---    ┆ ---    ┆ ---       ┆ ---           ┆   ┆ ---      ┆ ---         ┆ ---          ┆ ---  │
# │ i16    ┆ i16    ┆ f64       ┆ f64           ┆   ┆ f64      ┆ f64         ┆ f64          ┆ i8   │
# ╞════════╪════════╪═══════════╪═══════════════╪═══╪══════════╪═════════════╪══════════════╪══════╡
# │ 2022   ┆ 3290   ┆ 63.692308 ┆ 77.192308     ┆ … ┆ 0.387568 ┆ 0.493305    ┆ 0.230453     ┆ null │
# │ 2019   ┆ 3356   ┆ 65.9      ┆ 63.966667     ┆ … ┆ 0.4638   ┆ 0.459515    ┆ 0.219717     ┆ null │
# │ 2018   ┆ 3219   ┆ 62.206897 ┆ 62.034483     ┆ … ┆ 0.432542 ┆ 0.458874    ┆ 0.210998     ┆ null │
# │ 2022   ┆ 3413   ┆ 60.769231 ┆ 59.230769     ┆ … ┆ 0.477337 ┆ 0.412042    ┆ 0.231246     ┆ null │
# │ 2022   ┆ 3354   ┆ 50.413793 ┆ 71.103448     ┆ … ┆ 0.376122 ┆ 0.435618    ┆ 0.284896     ┆ null │
# │ 2023   ┆ 3375   ┆ 54.103448 ┆ 66.448276     ┆ … ┆ 0.38577  ┆ 0.456276    ┆ 0.228522     ┆ null │
# │ 2024   ┆ 3319   ┆ 75.151515 ┆ 70.787879     ┆ … ┆ 0.483938 ┆ 0.474166    ┆ 0.171967     ┆ null │
# │ 2026   ┆ 3479   ┆ 61.809524 ┆ 77.47619      ┆ … ┆ 0.460783 ┆ 0.559392    ┆ 0.217703     ┆ null │
# │ 2016   ┆ 3248   ┆ 57.758621 ┆ 65.896552     ┆ … ┆ 0.409438 ┆ 0.461417    ┆ 0.241894     ┆ null │
# │ 2015   ┆ 3117   ┆ 71.40625  ┆ 65.3125       ┆ … ┆ 0.489377 ┆ 0.45942     ┆ 0.215835     ┆ null │
# └────────┴────────┴───────────┴───────────────┴───┴──────────┴─────────────┴──────────────┴──────┘
